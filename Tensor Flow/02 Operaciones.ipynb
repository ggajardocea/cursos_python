# %% [markdown]
# # Tutorial de Tensor Flow.
# # Parte 2: Modelos lineales
# Lo primero a estudiar siempre al tratar de modelar es importar la data. Para esto es posible simplemente utilizar las funciones dadas por `pandas` y `numpy`.
# Sin embargo, dada la gran cantidad de modelos que se pueden utilizar en TF, es necesario tener en consideración el tipo de data. Para trabajos muy complejos, como procesamiento de imagen, se recomienda utilizar las funciones de importación de TF, que no se verán aca por temas de tiempo.
#
# En este ejemplo, se utilizará la data de casas de Boston (USA, no encontre datos buenos para Chile). Lo primero será cargar la data con `pandas` y procesarla con `numpy`, tienendo claridad de cual es nuestro directorio para evitar frustraciones.

# %%
# Se cambiar el directorio de trabajo para que encuentre los archivos en caso de que no lo haga
import os
import pandas as pd
import numpy as np
print("Actual directorio:", os.getcwd()) 

# Pero los datos están en data
houses = pd.read_csv("data/bostonhousing.txt")
print(houses.head())
# Out:
# Actual directorio: c:\Users\Gabriel\Documents\cursos_python
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# Se cambiar el directorio de trabajo para que encuentre los archivos en caso de que no lo haga
print("Actual directorio:", os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc80a480d5ec> in <module>()
#       1 # Se cambiar el directorio de trabajo para que encuentre los archivos en caso de que no lo haga
# ----> 2 print("Actual directorio:", os.getcwd())
#
# NameError: name 'os' is not defined
